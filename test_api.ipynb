# %%
import requests
import pandas as pd
from load_dotenv import load_dotenv
import random
from sqlalchemy import create_engine, text
from sqlalchemy.engine import Engine

from news_nlp.config import paths

# %%
load_dotenv(paths.ENV_FILE)
# Out:
# True

# %%
def get_engine(user="news_nlp_user", password="news_nlp_password", host="localhost", port="5433", db_name="news_nlp") -> Engine:
    url = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db_name}"
    engine = create_engine(url)
    return engine

# %%
def get_one_news_article(id_news: int):
    engine = get_engine()

    query = text("""
        SELECT title, content
        FROM news
        WHERE id_news = :id_news
    """)

    params = {"id_news": id_news}

    df = pd.read_sql(query, con=engine, params=params)

    return df

# %%
article = get_one_news_article('201111')
title = article.loc[0, "title"]
content = article.loc[0, "content"]
print(f"title: {title}\ncontent: {content}")
# Out:
# title: Mixed feelings as India farmers vacate protest sites near capital
# content: Sandhu , a 21-year-old model , tops a field of some 80 contestants in a pageant that was touched by @ @ @ @

# %%
url = "http://localhost:8005/v1/topics"

# %%
payload = {
    "title": f"{title}",
    "content": f"{content}"
}

# %%
response = requests.post(url, json=payload)
response.status
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 response = requests.post(url, json=payload)
# ----> 2 response.status
#
# AttributeError: 'Response' object has no attribute 'status'
